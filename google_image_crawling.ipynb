# %%
from google_images_download import google_images_download

# %%
def imageCrawling(keyword, dir):
    response = google_images_download.googleimagesdownload()
    
    arguments = {"keywords": keyword,
                 "limit": 250,
                 "print_urls": False,
                 "no_directory": True,
                 "chromedriver": "/Users/eren-shin/Desktop/handbag_crawler_for_training/chromedriver",
                 "output_directory": dir}
    
    paths = response.download(arguments)
    print(paths)

# %%
imageCrawling("circle bag", '/Users/eren-shin/Desktop/handbag_crawler_for_training/circle_bag/')
# Out:
# Item no.: 1 --> Item name = circle bag
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.circcbag-st-bla-go-1-gza-01.jpg
# Completed Image ====> 2.71N7IpROg8L._SX425_.jpg
# Completed Image ====> 3.900_2018-02-26_sm18_pow10887.jpg
# Completed Image ====> 4.00302577-04.jpg
# Completed Image ====> 5.P229_Fausset_Mushroom__20318.1550514054.jpg
# Completed Image ====> 6.Circle_Bag_Calf_Coated_Grey_Blue_Detail_1_180731_grande.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 7.TAH_Circle_Bag_Mini__18655.1564625674.JPG
# Completed Image ====> 8.P00312098.jpg
# Completed Image ====> 9.900_2017-12-11_sp18_pow0487.jpg
# Completed Image ====> 10.burgundy-mini-circle-bag.jpg
# Completed Image ====> 11.the-round-purse-leather-circle-bag-for-women-girls-circular-shape-bag-vintage-round-bag-brown-.jpg
# Completed Image ====> 12.cn15428707.jpg
# ...

# %%
imageCrawling("backpack", '/Users/eren-shin/Desktop/handbag_crawler_for_training/backpack/')
# Out:
# Item no.: 1 --> Item name = backpack
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.81ecNDjxhML._SY450_.jpg
# Completed Image ====> 2.81gn3B3KFvL._SY355_.jpg
# Completed Image ====> 3.81UbNUfvstL._UY606_.jpg
# Completed Image ====> 4.91cjHJE3JDL._SL1500_.jpg
# Completed Image ====> 5.Jansport_05.jpg
# Completed Image ====> 6.stm-2018-myth-collection-28l-backpack-slateblue-front-square_1.jpg
# Completed Image ====> 7.zoom_1735794.jpg
# Completed Image ====> 8.Frank_BackpackPhotoshop1_grande.png
# Completed Image ====> 9.81hOgG-CflL._SY355_.jpg
# Invalid or missing image format. Skipping...
# Invalid or missing image format. Skipping...
# Completed Image ====> 10.Supreme-Backpack-SS19-Red.jpg
# Completed Image ====> 11.5039732-ARU02.jpg
# Invalid or missing image format. Skipping...
# ...

# %%
imageCrawling("half circle bag", '/Users/eren-shin/Desktop/handbag_crawler_for_training/half_circle_bag/')
# Out:
# Item no.: 1 --> Item name = half circle bag
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.white_900x900_sm19_lookbook_semicirclebag_black_0605.jpg
# Completed Image ====> 2.51SIRYY2gFL._UX522_.jpg
# Completed Image ====> 3.0004736_half-circle-bracelet-bag-in-black_600.jpeg
# URLError on an image...trying next one... Error: HTTP Error 404: Not Found
# Completed Image ====> 4.B571C2FD-522F-41F2-A689-19F563406245_1200x.jpeg
# Invalid or missing image format. Skipping...
# Completed Image ====> 5.k59951-02_1.jpg
# Completed Image ====> 6.s-l300.jpg
# Completed Image ====> 7.s_5a8648d2a825a60590173321.jpeg
# Completed Image ====> 8.0E8A6544_7938cee1-a8d2-4a62-98dc-54b5a5ee41d4_1024x1024.jpg
# URLError on an image...trying next one... Error: HTTP Error 404: Not Found
# Completed Image ====> 9.il_794xN.1194307156_rm75.jpg
# Completed Image ====> 10.71A5MsI0bWL._SX425_.jpg
# ...

# %%
imageCrawling("square bag", '/Users/eren-shin/Desktop/handbag_crawler_for_training/square_bag/')
# Out:
# Item no.: 1 --> Item name = square bag
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.81JUDU3nFRL._SR500,500_.jpg
# Completed Image ====> 2.Square_Bag_rum_crossbody_1024x1024.jpg
# Completed Image ====> 3.1_3b82b485-e438-493e-8c01-833a1fbe0927_grande.jpg
# Completed Image ====> 4.b9c0498423701198c083c0e4ed5ea76b.jpg
# Completed Image ====> 5.9107c1JyjUL._SR500,500_.jpg
# Completed Image ====> 6.1557202161216802140.jpg
# IOError on an image...trying next one... Error: The read operation timed out
# Completed Image ====> 7.dd610b3980b6e1cfb53e19de6fb8cb03.jpg
# Completed Image ====> 8.Parker-Square-Acid-web_grande.jpg
# Completed Image ====> 9.chylak-square-bag-glossy-black-crocodile-800x800.jpg
# Completed Image ====> 10.Photo17_1200-web_grande.jpg
# Completed Image ====> 11.f55a5956c64b3e69da960cb7a3ced9a5.jpg
# Completed Image ====> 12.compass1487569835.jpg
# ...

# %%
imageCrawling("trapezoid bag", '/Users/eren-shin/Desktop/handbag_crawler_for_training/trapezoid_bag/')
# Out:
# Item no.: 1 --> Item name = trapezoid bag
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# URLError on an image...trying next one... Error: HTTP Error 404: Not Found
# Completed Image ====> 1.Trapezoid+Bag+rect.jpg
# Completed Image ====> 2.m_5cbd39f819c157e603ae8828.jpg
# Completed Image ====> 3.Trapezoid-leather-bag-1.jpg
# Completed Image ====> 4.03282_4White_1-897x1346.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 5.I9WB029EUMD500TU_06.jpg
# Completed Image ====> 6.q6b0q10fkb002_7.jpg
# Completed Image ====> 7.rosaire-orietta-calfskin-leather-satchel-top-handle-bag-trapezoid-shape-in-black-color-76113.jpg
# Completed Image ====> 8.1261f926261fd09ff348083fbad7d26e.png
# Completed Image ====> 9.large_stalvey-red-exclusive-trapezoid-mini-lizard-bag.jpg
# URLError on an image...trying next one... Error: HTTP Error 404: Not Found
# Completed Image ====> 10.118411_1.jpg
# ...

# %%
imageCrawling("hobo bag", '/Users/eren-shin/Desktop/handbag_crawler_for_training/hobo_bag/')
# Out:
# Item no.: 1 --> Item name = hobo bag
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1._106078337.jpg
# Completed Image ====> 2.market_slide_1.jpg
# Completed Image ====> 3.61JKth3VZnL._UY395_.jpg
# Completed Image ====> 4.11366402.jpg
# Completed Image ====> 5.71wzGK8dP7L._UY395_.jpg
# Completed Image ====> 6.SophieTan_grande_0317068e-4a57-476c-a0b1-f1209bf16f42_300x300.jpg
# Completed Image ====> 7.HH18EMCH57_MICHELLE_HOBO_1_BLACK_A_grande.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 8._105483569.jpg
# Completed Image ====> 9.CALLIELCLF_000034_FRONT.jpg
# Completed Image ====> 10.05880008_zi_black.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 11.louis-quatorze-3347-8710151-1.jpg
# Completed Image ====> 12.luxury_ladies_hobo_bags_made_of_leather_925bl.jpg
# Completed Image ====> 13.91uakT8EhLL._UL1500_.jpg
# ...

# %%
imageCrawling("bucket bag", '/Users/eren-shin/Desktop/handbag_crawler_for_training/bucket_bag/')
# Out:
# Item no.: 1 --> Item name = bucket bag
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.52660e38-4958-461c-818a-220cb14a3796.jpeg
# Completed Image ====> 2.71U5FdIwELL._UX679_.jpg
# Invalid or missing image format. Skipping...
# Invalid or missing image format. Skipping...
# Invalid or missing image format. Skipping...
# Completed Image ====> 3.45452370ls_13_a_v4.jpg
# Completed Image ====> 4.SS17_BUCKET-BAG_C_BROWN_FRONT.jpg
# Completed Image ====> 5.S19_Maria_Bucket_Bag_Cognac.jpg
# Completed Image ====> 6.Bucket_Bag_Saffiano_Blu_DETAIL_1_ad7b65e9-8f23-4115-8eae-aad1ba3e6f23_grande.jpg
# Completed Image ====> 7.857_217.jpg
# Completed Image ====> 8.WB001Q-3122-1.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 9.7359004040_2_2_1.jpg
# Completed Image ====> 10.bucketbags-1559754090.jpg
# Completed Image ====> 11.Zoe-Apostolou-Leather-Bag-2019-63.jpg
# ...
